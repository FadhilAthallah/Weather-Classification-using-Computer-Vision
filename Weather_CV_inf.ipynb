# %% [markdown]
# # **Model Inference**

# %% [markdown]
# ## **Import**

# %%
# Import Libraries

import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras import layers
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Input, Rescaling, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, Dense, BatchNormalization, LeakyReLU
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
import random


from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report


# Save model
import pickle
import joblib
import json

# %% [markdown]
# ## **Load Model**

# %%
# load model
model_final= load_model('model_func.keras')

# %% [markdown]
# ## **Load test Image**
# Pada loading image yang akan digunakan adalah gambar pada test set, dikarenakan gambar sama sekali belum digunakan dalam model dan termasuk gambar random yang dapat digunakan

# %%
# Define the path to your test dataset
test_data_dir = "C:/Users/Fadhil/Downloads/Gambar/dataset/alien_test"

# Create the ImageDataGenerator with rescaling
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load the test data using ImageDataGenerator
test = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(400, 400),
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=1
)
# Out:
# Found 30 images belonging to 5 classes.

# %%
# Load the model
model_final = load_model('model_func.keras')

# Get one batch of images and labels
images, labels = test.__getitem__(0)  # Get the first batch

# Select a random image from the batch
random_index = random.randint(0, images.shape[0] - 1)
random_image = images[random_index]
random_label = labels[random_index]

# Display the selected image
# Remove the normalization to display the image properly
plt.imshow(random_image)
plt.title('Selected Image')
plt.show()

# %% [markdown]
# ## **Prediction**

# %%
# Expand dimensions of the image to match the input shape of the model
image_array = np.expand_dims(random_image, axis=0)

# Predict the class of the image
predictions = model_final.predict(image_array)

# Get the predicted class index
predicted_class_index = np.argmax(predictions)

# Get the predicted class label
predicted_class_label = class_labels[predicted_class_index]

print(f'Predicted Class: {predicted_class_label}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted Class: cloud

# %% [markdown]
# * Prediksi benar

# %% [markdown]
# # **More Prediction**

# %% [markdown]
# ## **Pred 1**

# %%
# Load the model
model_final = load_model('model_func.keras')

# Get one batch of images and labels
images, labels = test.__getitem__(0)  # Get the first batch

# Select a random image from the batch
random_index = random.randint(0, images.shape[0] - 1)
random_image = images[random_index]
random_label = labels[random_index]

# Display the selected image
# Remove the normalization to display the image properly
plt.imshow(random_image)
plt.title('Selected Image')
plt.show()

# Expand dimensions of the image to match the input shape of the model
image_array = np.expand_dims(random_image, axis=0)

# Predict the class of the image
predictions = model_final.predict(image_array)

# Get the predicted class index
predicted_class_index = np.argmax(predictions)

# Get the predicted class label
predicted_class_label = class_labels[predicted_class_index]

print(f'Predicted Class: {predicted_class_label}')
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000163065CB790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Predicted Class: sunrise

# %% [markdown]
# * Prediksi salah

# %% [markdown]
# ## **Pred 2**

# %%
# Load the model
model_final = load_model('model_func.keras')

# Get one batch of images and labels
images, labels = test.__getitem__(0)  # Get the first batch

# Select a random image from the batch
random_index = random.randint(0, images.shape[0] - 1)
random_image = images[random_index]
random_label = labels[random_index]

# Display the selected image
# Remove the normalization to display the image properly
plt.imshow(random_image)
plt.title('Selected Image')
plt.show()

# Expand dimensions of the image to match the input shape of the model
image_array = np.expand_dims(random_image, axis=0)

# Predict the class of the image
predictions = model_final.predict(image_array)

# Get the predicted class index
predicted_class_index = np.argmax(predictions)

# Get the predicted class label
predicted_class_label = class_labels[predicted_class_index]

print(f'Predicted Class: {predicted_class_label}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Predicted Class: cloud

# %% [markdown]
# * Prediksi benar

# %% [markdown]
# ## **Pred 3**

# %%
# Load the model
model_final = load_model('model_func.keras')

# Get one batch of images and labels
images, labels = test.__getitem__(0)  # Get the first batch

# Select a random image from the batch
random_index = random.randint(0, images.shape[0] - 1)
random_image = images[random_index]
random_label = labels[random_index]

# Display the selected image
# Remove the normalization to display the image properly
plt.imshow(random_image)
plt.title('Selected Image')
plt.show()

# Expand dimensions of the image to match the input shape of the model
image_array = np.expand_dims(random_image, axis=0)

# Predict the class of the image
predictions = model_final.predict(image_array)

# Get the predicted class index
predicted_class_index = np.argmax(predictions)

# Get the predicted class label
predicted_class_label = class_labels[predicted_class_index]

print(f'Predicted Class: {predicted_class_label}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Predicted Class: sunrise

# %% [markdown]
# # **Inference conclusion**

# %% [markdown]
# | **Prediksi**     | **Hasil Prediksi** |
# |----------------|----------|
# | 1 | Salah    |
# | 2 | Benar    |
# | 3 | Benar   |

# %% [markdown]
# * Berdasarkan hasil prediksi, dari 3, 1 mendapatkan hasil prediksi yang salah, ini diketahui terjadi karena nilai accuracy dari model yang hanya memiliki kisaran 60%, dimana terdapat persentase kesalahan sebesar 40%
# * Secara keseluruhan model dapat digunakan untuk memprediksi data random
